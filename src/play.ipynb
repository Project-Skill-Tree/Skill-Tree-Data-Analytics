# %%
import stdata
r = stdata.Reader()

# %%
r.order_skills_by_popularity()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /Users/alex/SkillTreeDataAnalysis/Skill-Tree-Data-Analytics/src/play.ipynb Celda 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alex/SkillTreeDataAnalysis/Skill-Tree-Data-Analytics/src/play.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> r.order_skills_by_popularity()
#
# File ~/SkillTreeDataAnalysis/Skill-Tree-Data-Analytics/src/stdata.py:28, in Reader.order_skills_by_popularity(self, user_parameter)
#      26 total_list = []
#      27 users = self.users.find(user_parameter)
# ---> 28 for user in users:
#      29     for skill in user["skillscompleted"]:
#      30         total_list.append(skill)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/cursor.py:1248, in Cursor.next(self)
#    1246 if self.__empty:
#    1247     raise StopIteration
# ...
